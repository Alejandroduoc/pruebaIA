# %% [markdown]
# # 3. Chain-of-Thought (CoT) Prompting - Razonamiento Paso a Paso
#
# ## Objetivos de Aprendizaje
# - Comprender el concepto de Chain-of-Thought (CoT) prompting
# - Implementar CoT con y sin ejemplos
# - Aplicar CoT a problemas complejos y razonamiento lógico
# - Combinar CoT con otras técnicas de prompting
#
# ## ¿Qué es Chain-of-Thought?
#
# Chain-of-Thought (CoT) es una técnica que hace que el modelo "**piense en voz alta**" mostrando su proceso de razonamiento paso a paso antes de llegar a la respuesta final.
#
# ### Principio Básico:
# En lugar de saltar directamente a la respuesta, el modelo:
# 1. **Descompone** el problema en pasos
# 2. **Razona** cada paso explícitamente
# 3. **Construye** hacia la solución final
# 4. **Proporciona** la respuesta con justificación
#
# ### Ventajas:
# - **Mejor precisión**: Especialmente en problemas complejos
# - **Transparencia**: Puedes ver el razonamiento
# - **Debugging**: Identificar dónde falla el razonamiento
# - **Confianza**: Mayor seguridad en la respuesta
#
# ### Casos de Uso Ideales:
# - Problemas matemáticos
# - Razonamiento lógico
# - Análisis complejos
# - Toma de decisiones
# - Resolución de problemas multi-paso

# %%
# Configuración inicial
from langchain_openai import ChatOpenAI
from langchain.schema import HumanMessage
import os
import time

# Configurar el modelo
llm = ChatOpenAI(
    base_url=os.getenv("OPENAI_BASE_URL"),
    api_key=os.getenv("GITHUB_TOKEN"),
    model="gpt-4.1",
    temperature=0.1
)

print("✓ Modelo configurado para Chain-of-Thought")
print("✓ Temperature baja para razonamiento consistente")
# Out:
# ✓ Modelo configurado para Chain-of-Thought
# ✓ Temperature baja para razonamiento consistente

# %% [markdown]
# ## Comparación: Sin CoT vs Con CoT
#
# Veamos la diferencia dramática que puede hacer CoT en problemas complejos.

# %%
# Comparación directa: razonamiento directo vs CoT
def comparar_sin_vs_con_cot():
    print("=== COMPARACIÓN: SIN CoT vs CON CoT ===")
    
    # Problema complejo que requiere múltiples pasos
    problema = """Una tienda tiene una promoción: 'Compra 2 productos y obtén 30% de descuento en el más barato'. 
    Juan compra una camiseta de 45€, unos zapatos de 120€ y una chaqueta de 80€. 
    ¿Cuánto paga en total?"""
    
    # Prompt sin CoT
    prompt_sin_cot = f"""Resuelve este problema:
    
{problema}
    
Respuesta:"""
    
    # Prompt con CoT
    prompt_con_cot = f"""Resuelve este problema paso a paso:
    
{problema}
    
Piensa paso a paso:
1. Primero identifica los productos y precios
2. Determina cómo se aplica la promoción
3. Calcula el descuento
4. Calcula el total final
    
Razonamiento:"""
    
    # Probar sin CoT
    print("\n1. SIN CHAIN-OF-THOUGHT:")
    print("-" * 30)
    try:
        response_sin = llm.invoke([HumanMessage(content=prompt_sin_cot)])
        print(response_sin.content)
    except Exception as e:
        print(f"Error: {e}")
    
    print("\n" + "="*60)
    
    # Probar con CoT
    print("\n2. CON CHAIN-OF-THOUGHT:")
    print("-" * 30)
    try:
        response_con = llm.invoke([HumanMessage(content=prompt_con_cot)])
        print(response_con.content)
    except Exception as e:
        print(f"Error: {e}")
    
    print("\n=== ANÁLISIS ===")
    print("• Sin CoT: Puede llegar a respuesta incorrecta o saltar pasos")
    print("• Con CoT: Muestra razonamiento completo y reduce errores")
    print("• CoT especialmente útil para problemas multi-paso")

# Ejecutar comparación
comparar_sin_vs_con_cot()
# Out:
# === COMPARACIÓN: SIN CoT vs CON CoT ===
#
# 1. SIN CHAIN-OF-THOUGHT:
# ------------------------------
# Vamos a resolver el problema paso a paso:
#
# **Productos comprados:**
# - Camiseta: 45 €
# - Zapatos: 120 €
# - Chaqueta: 80 €
#
# **Promoción:**
# "Compra 2 productos y obtén 30% de descuento en el más barato."
#
# **¿Cómo se aplica la promoción?**
# La promoción se aplica por cada par de productos comprados.
# Juan compra 3 productos, así que puede aprovechar la promoción una vez (con dos productos), y el tercero lo paga sin descuento.
#
# **¿Cuál es la mejor forma de aplicar la promoción para pagar menos?**
# La promoción se aplica al más barato de los dos productos seleccionados.
# Para maximizar el descuento, conviene agrupar los dos productos más caros y dejar el más barato aparte.
#
# Pero, veamos las opciones:
#
# - Si agrupa **zapatos (120 €) y chaqueta (80 €)**:
#   El descuento se aplica a la chaqueta (80 €):
#   30% de 80 € = 24 €
#   Precio de los dos: 120 € + (80 € - 24 €) = 120 € + 56 € = **176 €**
#   La camiseta (45 €) se paga sin descuento.
#   Total: 176 € + 45 € = **221 €**
#
# - Si agrupa **zapatos (120 €) y camiseta (45 €)**:
#   El descuento se aplica a la camiseta (45 €):
#   30% de 45 € = 13,50 €
#   Precio de los dos: 120 € + (45 € - 13,50 €) = 120 € + 31,50 € = **151,50 €**
#   La chaqueta (80 €) se paga sin descuento.
#   Total: 151,50 € + 80 € = **231,50 €**
#
# - Si agrupa **chaqueta (80 €) y camiseta (45 €)**:
#   El descuento se aplica a la camiseta (45 €):
#   30% de 45 € = 13,50 €
#   Precio de los dos: 80 € + (45 € - 13,50 €) = 80 € + 31,50 € = **111,50 €**
#   Los zapatos (120 €) se pagan sin descuento.
#   Total: 111,50 € + 120 € = **231,50 €**
#
# **La mejor opción es la primera:**
# Agrupar los dos productos más caros (zapatos y chaqueta), y el descuento se aplica a la chaqueta.
#
# **Respuesta final:**
#
# > **Juan paga en total 221 €.**
#
# **Desglose:**
# - Zapatos: 120 €
# - Chaqueta: 80 € - 24 € = 56 €
# - Camiseta: 45 €
# - **Total: 120 € + 56 € + 45 € = 221 €**
#
# ============================================================
#
# 2. CON CHAIN-OF-THOUGHT:
# ------------------------------
# Claro, vamos paso a paso:
#
# **1. Identifica los productos y precios**
#
# Juan compra:
# - Camiseta: 45€
# - Zapatos: 120€
# - Chaqueta: 80€
#
# **2. Determina cómo se aplica la promoción**
#
# La promoción dice: "Compra 2 productos y obtén 30% de descuento en el más barato".
#
# - Si compras 2 productos, el más barato de esos dos tiene 30% de descuento.
# - Juan compra 3 productos. Normalmente, la promoción se aplica por cada par de productos comprados. Pero en la mayoría de tiendas, si compras más de dos productos, la promoción se aplica solo una vez (a menos que se especifique lo contrario).
#
# **¿Cómo se aplica aquí?**
# - Si la tienda permite aplicar la promoción varias veces, podrías agrupar los productos en pares y aplicar el descuento dos veces.
# - Si solo se aplica una vez, se eligen los dos productos más baratos para la promoción.
#
# **Vamos a asumir la opción más común: la promoción se aplica solo una vez por compra.**
#
# **3. Calcula el descuento**
#
# - Los dos productos más baratos son: Camiseta (45€) y Chaqueta (80€).
# - El más barato de estos dos es la Camiseta (45€).
# - El descuento es 30% sobre 45€.
#
# Descuento = 45€ × 0.30 = **13,50€**
#
# **4. Calcula el total final**
#
# - Precio original de los tres productos: 45€ + 120€ + 80€ = **245€**
# - Descuento aplicado: **13,50€**
#
# **Total a pagar:**
# 245€ - 13,50€ = **231,50€**
#
# ---
#
# **Respuesta final:**
# Juan paga **231,50€** en total.
#
# === ANÁLISIS ===
# • Sin CoT: Puede llegar a respuesta incorrecta o saltar pasos
# • Con CoT: Muestra razonamiento completo y reduce errores
# • CoT especialmente útil para problemas multi-paso

# %% [markdown]
# ## Zero-Shot Chain-of-Thought
#
# La forma más simple de CoT: simplemente pedirle al modelo que "piense paso a paso".

# %%
# Zero-shot CoT: solo agregar "piensa paso a paso"
def zero_shot_cot():
    print("=== ZERO-SHOT CHAIN-OF-THOUGHT ===")
    
    problemas = [
        "Si un tren viaja a 80 km/h y necesita llegar a una ciudad que está a 240 km, pero se detiene 15 minutos en una estación intermedia, ¿cuánto tiempo total toma el viaje?",
        "Una empresa tiene 150 empleados. El 40% trabaja en desarrollo, el 25% en ventas, el 20% en marketing y el resto en administración. Si cada empleado de desarrollo gana 50,000€ anuales, ¿cuál es el costo anual solo del departamento de desarrollo?",
        "María tiene el triple de edad que su hermana Ana. En 5 años, María tendrá el doble de la edad que tendrá Ana. ¿Cuántos años tiene cada una ahora?"
    ]
    
    for i, problema in enumerate(problemas, 1):
        print(f"\n{i}. PROBLEMA:")
        print(f"{problema}")
        
        # Prompt zero-shot CoT
        prompt = f"{problema}\n\nPiensa paso a paso:"
        
        try:
            response = llm.invoke([HumanMessage(content=prompt)])
            print("\nSOLUCIÓN:")
            print(response.content)
            
            # Análisis básico del razonamiento
            pasos = response.content.count('\n')
            tiene_calculo = any(op in response.content for op in ['+', '-', '*', '/', '=', '%'])
            
            print(f"\nAnálisis: {pasos} líneas de razonamiento, {'con' if tiene_calculo else 'sin'} cálculos explícitos")
            
        except Exception as e:
            print(f"Error: {e}")
        
        print("-" * 80)

# Ejecutar zero-shot CoT
zero_shot_cot()
# Out:
# === ZERO-SHOT CHAIN-OF-THOUGHT ===
#
# 1. PROBLEMA:
# Si un tren viaja a 80 km/h y necesita llegar a una ciudad que está a 240 km, pero se detiene 15 minutos en una estación intermedia, ¿cuánto tiempo total toma el viaje?
#
# SOLUCIÓN:
# ¡Claro! Vamos a resolverlo paso a paso:
#
# **1. Calcular el tiempo de viaje sin detenerse**
#
# La fórmula básica es:
#
# \[
# \text{Tiempo} = \frac{\text{Distancia}}{\text{Velocidad}}
# \]
#
# - Distancia: 240 km
# - Velocidad: 80 km/h
#
# \[
# \text{Tiempo} = \frac{240\, \text{km}}{80\, \text{km/h}} = 3\, \text{horas}
# \]
#
# ---
#
# **2. Sumar el tiempo de la parada**
#
# La parada es de **15 minutos**. Vamos a convertirlo a horas:
#
# \[
# 15\, \text{minutos} = \frac{15}{60} = 0.25\, \text{horas}
# \]
#
# ---
#
# **3. Calcular el tiempo total**
#
# \[
# \text{Tiempo total} = \text{Tiempo de viaje} + \text{Tiempo de parada}
# \]
# \[
# \text{Tiempo total} = 3\, \text{horas} + 0.25\, \text{horas} = 3.25\, \text{horas}
# \]
#
# ---
#
# **4. Convertir el resultado a horas y minutos**
#
# 0.25 horas = 15 minutos
#
# Entonces,
#
# \[
# \text{Tiempo total} = 3\, \text{horas
#
# Análisis: 47 líneas de razonamiento, con cálculos explícitos
# --------------------------------------------------------------------------------
#
# 2. PROBLEMA:
# Una empresa tiene 150 empleados. El 40% trabaja en desarrollo, el 25% en ventas, el 20% en marketing y el resto en administración. Si cada empleado de desarrollo gana 50,000€ anuales, ¿cuál es el costo anual solo del departamento de desarrollo?
#
# SOLUCIÓN:
# Vamos paso a paso:
#
# **1. Calcular cuántos empleados hay en desarrollo:**
#
# El 40% de los 150 empleados trabaja en desarrollo.
#
# \[
# \text{Empleados en desarrollo} = 40\% \times 150 = 0.40 \times 150 = 60
# \]
#
# **2. Calcular el costo anual del departamento de desarrollo:**
#
# Cada empleado de desarrollo gana 50,000€ al año.
#
# \[
# \text{Costo anual desarrollo} = \text{Empleados en desarrollo} \times \text{Salario anual por empleado}
# \]
# \[
# \text{Costo anual desarrollo} = 60 \times 50,000€ = 3,000,000€
# \]
#
# **Respuesta final:**
#
# El costo anual solo del departamento de desarrollo es **3,000,000€**.
#
# Análisis: 23 líneas de razonamiento, con cálculos explícitos
# --------------------------------------------------------------------------------
#
# 3. PROBLEMA:
# María tiene el triple de edad que su hermana Ana. En 5 años, María tendrá el doble de la edad que tendrá Ana. ¿Cuántos años tiene cada una ahora?
#
# SOLUCIÓN:
# Vamos a resolver el problema paso a paso:
#
# **1. Definimos las variables:**
#
# - Sea \( x \) la edad actual de Ana.
# - Entonces, la edad actual de María es \( 3x \) (porque María tiene el triple de edad que Ana).
#
# **2. Analizamos la situación en 5 años:**
#
# - En 5 años, Ana tendrá \( x + 5 \) años.
# - En 5 años, María tendrá \( 3x + 5 \) años.
#
# Según el enunciado, en 5 años María tendrá el doble de la edad que tendrá Ana:
#
# \[
# 3x + 5 = 2(x + 5)
# \]
#
# **3. Resolvemos la ecuación:**
#
# \[
# 3x + 5 = 2(x + 5)
# \]
# \[
# 3x + 5 = 2x + 10
# \]
#
# Restamos \( 2x \) a ambos lados:
#
# \[
# 3x - 2x + 5 = 10
# \]
# \[
# x + 5 = 10
# \]
#
# Restamos 5 a ambos lados:
#
# \[
# x = 5
# \]
#
# **4. Calculamos las edades actuales:**
#
# - Ana tiene \( x = 5 \) años.
# - María tiene \( 3x = 15 \) años.
#
# **5. Verificamos:
#
# Análisis: 47 líneas de razonamiento, con cálculos explícitos
# --------------------------------------------------------------------------------

# %% [markdown]
# ## Few-Shot Chain-of-Thought
#
# Combinamos CoT con ejemplos para mostrar el patrón de razonamiento deseado.

# %%
# Few-shot CoT: ejemplos con razonamiento paso a paso
def few_shot_cot():
    print("=== FEW-SHOT CHAIN-OF-THOUGHT ===")

    # Nuevo problema para resolver
    nuevo_problema = "Un parking cobra 3€ la primera hora y 2€ cada hora adicional. Si alguien paga 15€, ¿cuántas horas estuvo estacionado?"
    
    # Prompt con ejemplos de razonamiento
    prompt_few_shot_cot = f"""Resuelve problemas matemáticos mostrando el razonamiento paso a paso:
    
Problema: Una pizza cuesta 12€ y cada ingrediente extra cuesta 1.50€. Si Pedro paga 18€, ¿cuántos ingredientes extra pidió?
Razonamiento:
1. Precio base de la pizza: 12€
2. Total pagado: 18€
3. Dinero gastado en extras: 18€ - 12€ = 6€
4. Costo por ingrediente extra: 1.50€
5. Número de ingredientes: 6€ ÷ 1.50€ = 4 ingredientes
Respuesta: Pedro pidió 4 ingredientes extra.
    
Problema: En una clase hay 24 estudiantes. Si se forman grupos de 6 estudiantes cada uno, ¿cuántos grupos se pueden formar? Si sobra algún estudiante, ¿cuántos?
Razonamiento:
1. Total de estudiantes: 24
2. Estudiantes por grupo: 6
3. División: 24 ÷ 6 = 4 grupos exactos
4. Verificación: 4 × 6 = 24 estudiantes
5. Resto: 24 - 24 = 0 estudiantes sobran
Respuesta: Se pueden formar 4 grupos completos y no sobra ningún estudiante.
    
Problema: {nuevo_problema}
Razonamiento:"""
  
    try:
        
        response = llm.invoke([HumanMessage(content=prompt_few_shot_cot)])
        print("PROBLEMA A RESOLVER:")
        print(nuevo_problema)
        print("\nSOLUCIÓN CON RAZONAMIENTO:")
        print(response.content)
        
        # Verificar si siguió el patrón
        razonamiento = response.content
        tiene_pasos_numerados = bool(re.search(r'\d+\.', razonamiento))
        tiene_calculos = any(op in razonamiento for op in ['=', '+', '-', '*', '/', '€'])
        tiene_respuesta_final = 'respuesta' in razonamiento.lower()
        
        print("\n=== ANÁLISIS DEL PATRÓN ===")
        print(f"✓ Pasos numerados: {'Sí' if tiene_pasos_numerados else 'No'}")
        print(f"✓ Cálculos explícitos: {'Sí' if tiene_calculos else 'No'}")
        print(f"✓ Respuesta final clara: {'Sí' if tiene_respuesta_final else 'No'}")
        
    except Exception as e:
        print(f"Error: {e}")

# Ejecutar few-shot CoT
import re
few_shot_cot()
# Out:
# === FEW-SHOT CHAIN-OF-THOUGHT ===
# PROBLEMA A RESOLVER:
# Un parking cobra 3€ la primera hora y 2€ cada hora adicional. Si alguien paga 15€, ¿cuántas horas estuvo estacionado?
#
# SOLUCIÓN CON RAZONAMIENTO:
# Claro, vamos a resolver el problema paso a paso:
#
# **Problema:** Un parking cobra 3 € la primera hora y 2 € cada hora adicional. Si alguien paga 15 €, ¿cuántas horas estuvo estacionado?
#
# **Razonamiento:**
#
# 1. **Precio de la primera hora:** 3 €
# 2. **Precio de cada hora adicional:** 2 €
# 3. **Total pagado:** 15 €
#
# **Paso 1:** Restamos el precio de la primera hora al total pagado para saber cuánto se gastó en horas adicionales.
#
# 15 € (total pagado) - 3 € (primera hora) = 12 € (gastado en horas adicionales)
#
# **Paso 2:** Calculamos cuántas horas adicionales corresponden a 12 €, sabiendo que cada hora adicional cuesta 2 €.
#
# 12 € ÷ 2 € = 6 horas adicionales
#
# **Paso 3:** Sumamos la primera hora a las horas adicionales para obtener el total de horas estacionado.
#
# 1 hora (primera) + 6 horas (adicionales) = **7 horas**
#
# **Respuesta:**
# La persona estuvo estacionada **7 horas**.
#
# === ANÁLISIS DEL PATRÓN ===
# ✓ Pasos numerados: Sí
# ✓ Cálculos explícitos: Sí
# ✓ Respuesta final clara: Sí

# %% [markdown]
# ## CoT para Razonamiento Lógico
#
# Chain-of-Thought es especialmente poderoso para problemas de lógica y deducción.

# %%
# CoT para problemas de lógica
def cot_razonamiento_logico():
    print("=== CoT PARA RAZONAMIENTO LÓGICO ===")
    
    # Problema de lógica clásico
    problema_logica = """En una mesa redonda se sientan 5 personas: Ana, Bruno, Carlos, Diana y Elena.
    - Ana no está al lado de Bruno
    - Carlos está exactamente frente a Diana
    - Elena está al lado derecho de Ana
    - Bruno está al lado de Carlos
    
¿Cuál es la disposición completa alrededor de la mesa?"""
    
    prompt_logica = f"""Resuelve este problema de lógica paso a paso:
    
{problema_logica}
    
Razona sistemáticamente:
1. Identifica las restricciones
2. Establece relaciones conocidas
3. Deduce posiciones paso a paso
4. Verifica que se cumplan todas las condiciones
    
Proceso de deducción:"""
    
    try:
        response = llm.invoke([HumanMessage(content=prompt_logica)])
        print("PROBLEMA DE LÓGICA:")
        print(problema_logica)
        print("\nPROCESO DE RAZONAMIENTO:")
        print(response.content)
        
    except Exception as e:
        print(f"Error: {e}")

# Ejecutar razonamiento lógico
cot_razonamiento_logico()
# Out:
# === CoT PARA RAZONAMIENTO LÓGICO ===
# PROBLEMA DE LÓGICA:
# En una mesa redonda se sientan 5 personas: Ana, Bruno, Carlos, Diana y Elena.
#     - Ana no está al lado de Bruno
#     - Carlos está exactamente frente a Diana
#     - Elena está al lado derecho de Ana
#     - Bruno está al lado de Carlos
#
# ¿Cuál es la disposición completa alrededor de la mesa?
#
# PROCESO DE RAZONAMIENTO:
# ¡Vamos a resolver el problema paso a paso!
#
# ### 1. **Identifica las restricciones**
#
# - **R1:** Ana no está al lado de Bruno.
# - **R2:** Carlos está exactamente frente a Diana.
# - **R3:** Elena está al lado derecho de Ana.
# - **R4:** Bruno está al lado de Carlos.
#
# ### 2. **Establece relaciones conocidas**
#
# En una mesa redonda de 5 personas, cada persona tiene dos vecinos (izquierda y derecha), y la persona "frente" está a dos lugares de distancia.
#
# - Si numeramos los asientos del 1 al 5 en sentido horario, la persona en el asiento 1 tiene a su derecha la del asiento 2, y a su izquierda la del asiento 5.
# - La persona "frente" a la del asiento 1 está en el asiento 3.
#
# ### 3. **Deduce posiciones paso a paso**
#
# #### **Paso 1: Ubica a Carlos y Diana**
#
# Por **R2**, Carlos y Diana están frente a frente.
# Supongamos:
#
# - Carlos en el asiento 1 → Diana en el asiento 3
# - O Carlos en el asiento 2 → Diana en el asiento 4
# - O Carlos en el asiento 3 → Diana en el asiento 5
# - O Carlos en el asiento 4 → Diana en el asiento 1
# - O Carlos en el asiento 5 → Diana en el asiento 2
#
# Pero como hay 5 personas, solo hay una posición en la que dos personas pueden estar "exactamente frente": asientos 1 y 3, 2 y 4, 3 y 5, 4 y 1, 5 y 2.
#
# Vamos a elegir **Carlos en el asiento 1, Diana en el asiento 3** (los demás casos son equivalentes por simetría).
#
# #### **Paso 2: Ubica a Elena respecto a Ana**
#
# Por **R3**, Elena está al lado derecho de Ana.
#
# - Si Ana está en el asiento X, Elena está en el asiento X+1 (en sentido horario).
#
# #### **Paso 3: Bruno está al lado de Carlos**
#
# Por **R4**, Bruno está al lado de Carlos (asiento 1).
# Los vecinos de Carlos (asiento 1) son los asientos 2 y 5.
#
# Así que Bruno está en el asiento 2 o 5.
#
# #### **Paso 4: Ana no está al lado de Bruno**
#
# Por **R1**, Ana no puede estar en los asientos vecinos de Bruno.
#
# #### **Paso 5: Coloca a todos**
#
# Vamos a probar las posiciones:
#
# - Asiento 1: Carlos
# - Asiento 3: Diana
#
# Los asientos libres son 2, 4, 5.
#
# Bruno debe estar en 2 o 5.
#
# ##### **Caso A: Bruno en el asiento 2**
#
# - Asiento 2: Bruno
# - Asiento 1: Carlos
# - Asiento 3: Diana
#
# Quedan asientos 4 y 5 para Ana y Elena.
#
# Elena debe estar al lado derecho de Ana.
# Si Ana está en el asiento 4, Elena estaría en el 5.
# Si Ana está en el asiento 5, Elena estaría en el 1 (pero el 1 ya está ocupado por Carlos).
#
# Así que:
#
# - Asiento 4: Ana
# - Asiento 5: Elena
#
# Ahora, verifiquemos las restricciones:
#
# - **R1:** Ana (4) no está al lado de Bruno (2). Los vecinos de Ana son 3 (Diana) y 5 (Elena). OK.
# - **R2:** Carlos (1) está frente a Diana (3). OK.
# - **R3:** Elena (5) está al lado derecho de Ana (4). En sentido horario, sí: de 4 a 5. OK.
# - **R4:** Bruno (2) está al lado de Carlos (1). Sí, 1 y 2 son vecinos. OK.
#
# ¡Todas las restricciones se cumplen!
#
# ##### **Caso B: Bruno en el asiento 5**
#
# - Asiento 5: Bruno
# - Asiento 1: Carlos
# - Asiento 3: Diana
#
# Quedan asientos 2 y 4 para Ana y Elena.
#
# Elena debe estar al lado derecho de Ana.
#
# Si Ana está en el asiento 2, Elena estaría en el 3 (pero 3 está ocupado por Diana).
# Si Ana está en el asiento 4, Elena estaría en el 5 (pero 5 está ocupado por Bruno).
#
# No es posible.
#
# ### 4. **Verifica que se cumplan todas las condiciones**
#
# Ya lo hicimos en el caso A.
#
# ---
#
# ## **Solución final**
#
# La disposición alrededor de la mesa, en sentido horario, es:
#
# 1. **Carlos**
# 2. **Bruno**
# 3. **Diana**
# 4. **Ana**
# 5. **Elena**
#
# **Sentados en círculo:**
# - Carlos (1) tiene a Bruno (2) a su derecha y Elena (5) a su izquierda.
# - Bruno (2) tiene a Diana (3) a su derecha y Carlos (1) a su izquierda.
# - Diana (3) tiene a Ana (4) a su derecha y Bruno (2) a su izquierda.
# - Ana (4) tiene a Elena (5) a su derecha y Diana (3) a su izquierda.
# - Elena (5) tiene a Carlos (1) a su derecha y Ana (4) a su izquierda.
#
# ---
#
# **Resumen de razonamiento:**
# - Ubicamos a Carlos y Diana frente a frente.
# - Bruno debe estar al lado de Carlos.
# - Elena debe estar al lado derecho de Ana.
# - Ana no puede estar al lado de Bruno.
# - Solo una disposición cumple todas las condiciones.
#
# **Respuesta final:**
# **Carlos, Bruno, Diana, Ana, Elena** (en sentido horario).

# %%
# CoT para análisis de casos complejos
def cot_analisis_complejo():
    print("=== CoT PARA ANÁLISIS COMPLEJO ===")
    
    # Caso de negocio complejo
    caso_negocio = """Una startup de software tiene las siguientes métricas:
    - 10,000 usuarios activos mensuales
    - Tasa de conversión a premium: 5%
    - Precio premium: 29€/mes
    - Costo de adquisición por usuario: 15€
    - Retención mensual: 85%
    - Costos operativos mensuales: 12,000€
    
La empresa está considerando reducir el precio a 19€/mes para aumentar la conversión a 8%. 
¿Es una buena decisión financiera?"""
    
    prompt_analisis = f"""Analiza este caso de negocio paso a paso:
    
{caso_negocio}
    
Estructura tu análisis:
1. Calcula métricas del escenario actual
2. Calcula métricas del escenario propuesto
3. Compara ingresos y costos
4. Considera factores adicionales
5. Proporciona recomendación fundamentada
    
Análisis detallado:"""
    
    try:
        response = llm.invoke([HumanMessage(content=prompt_analisis)])
        print("CASO DE NEGOCIO:")
        print(caso_negocio)
        print("\nANÁLISIS PASO A PASO:")
        print(response.content)
        
        # Verificar completitud del análisis
        analisis = response.content.lower()
        elementos_clave = [
            'ingresos', 'costos', 'beneficio', 'actual', 'propuesto', 
            'recomendación', 'conversión', 'usuarios'
        ]
        elementos_presentes = sum(1 for elemento in elementos_clave if elemento in analisis)
        
        print(f"\n=== COMPLETITUD DEL ANÁLISIS ===")
        print(f"✓ Elementos clave cubiertos: {elementos_presentes}/{len(elementos_clave)}")
        print(f"✓ Análisis completo: {'Sí' if elementos_presentes >= 6 else 'Parcial'}")
        
    except Exception as e:
        print(f"Error: {e}")

# Ejecutar análisis complejo
cot_analisis_complejo()
# Out:
# === CoT PARA ANÁLISIS COMPLEJO ===
# CASO DE NEGOCIO:
# Una startup de software tiene las siguientes métricas:
#     - 10,000 usuarios activos mensuales
#     - Tasa de conversión a premium: 5%
#     - Precio premium: 29€/mes
#     - Costo de adquisición por usuario: 15€
#     - Retención mensual: 85%
#     - Costos operativos mensuales: 12,000€
#
# La empresa está considerando reducir el precio a 19€/mes para aumentar la conversión a 8%.
# ¿Es una buena decisión financiera?
#
# ANÁLISIS PASO A PASO:
# Claro, aquí tienes un análisis detallado y estructurado del caso:
#
# ---
#
# ## 1. **Métricas del escenario actual**
#
# **Usuarios activos mensuales:** 10,000
# **Tasa de conversión a premium:** 5%
# **Usuarios premium:** 10,000 × 5% = **500**
# **Precio premium:** 29€/mes
# **Ingresos mensuales:** 500 × 29€ = **14,500€**
#
# **Retención mensual:** 85%
# **Churn mensual:** 15%
# **Nuevos usuarios premium necesarios para mantener base:**
# Cada mes se pierden 15% de 500 = **75** usuarios premium
# Para mantener 500 usuarios premium, hay que captar 75 nuevos premium cada mes.
#
# **Costo de adquisición por usuario:** 15€
# **CAC mensual:** 75 × 15€ = **1,125€**
#
# **Costos operativos mensuales:** 12,000€
#
# **Costos totales mensuales:** 12,000€ + 1,125€ = **13,125€**
#
# **Beneficio mensual:** 14,500€ - 13,125€ = **1,375€**
#
# ---
#
# ## 2. **Métricas del escenario propuesto**
#
# **Nuevo precio premium:** 19€/mes
# **Nueva tasa de conversión:** 8%
# **Usuarios premium:** 10,000 × 8% = **800**
# **Ingresos mensuales:** 800 × 19€ = **15,200€**
#
# **Retención mensual:** 85% (se asume igual)
# **Churn mensual:** 15%
# **Nuevos usuarios premium necesarios para mantener base:**
# Cada mes se pierden 15% de 800 = **120** usuarios premium
# Para mantener 800 usuarios premium, hay que captar 120 nuevos premium cada mes.
#
# **Costo de adquisición por usuario:** 15€
# **CAC mensual:** 120 × 15€ = **1,800€**
#
# **Costos operativos mensuales:** 12,000€
#
# **Costos totales mensuales:** 12,000€ + 1,800€ = **13,800€**
#
# **Beneficio mensual:** 15,200€ - 13,800€ = **1,400€**
#
# ---
#
# ## 3. **Comparación de ingresos y costos**
#
# | Métrica                | Actual      | Propuesto   | Diferencia   |
# |------------------------|-------------|-------------|--------------|
# | Usuarios premium       | 500         | 800         | +300         |
# | Ingresos mensuales     | 14,500€     | 15,200€     | +700€        |
# | CAC mensual            | 1,125€      | 1,800€      | +675€        |
# | Costos operativos      | 12,000€     | 12,000€     | 0€           |
# | Costos totales         | 13,125€     | 13,800€     | +675€        |
# | Beneficio mensual      | 1,375€      | 1,400€      | +25€         |
#
# **Conclusión numérica:**
# La reducción de precio aumenta el número de usuarios premium y los ingresos, pero también incrementa el CAC. El beneficio mensual solo aumenta en **25€**.
#
# ---
#
# ## 4. **Factores adicionales a considerar**
#
# - **Elasticidad de la demanda:** El aumento de conversión es modesto (de 5% a 8%) frente a la reducción de precio (de 29€ a 19€). ¿Podría el precio más bajo atraer aún más usuarios premium si se acompaña de marketing?
# - **Percepción de valor:** Reducir el precio puede afectar la percepción de calidad del producto.
# - **Retención:** Si el precio más bajo mejora la retención, el beneficio podría aumentar más de lo calculado.
# - **Upselling/Cross-selling:** Más usuarios premium pueden abrir oportunidades para vender servicios adicionales.
# - **Competencia:** Un precio más bajo puede ser una ventaja competitiva.
# - **Sostenibilidad:** El margen por usuario premium baja de 29€ a 19€, lo que puede limitar reinversión en producto y marketing.
# - **Escalabilidad:** Si la base de usuarios activos crece, el escenario propuesto podría ser más ventajoso.
#
# ---
#
# ## 5. **Recomendación fundamentada**
#
# **Financieramente**, la reducción de precio **no genera un aumento significativo en el beneficio mensual** (solo 25€ más), aunque sí incrementa la base de usuarios premium y los ingresos brutos. El margen por usuario baja, y el CAC total sube.
#
# **Recomendación:**
# - **No recomendaría la reducción de precio solo por el beneficio financiero inmediato**, ya que el impacto es marginal.
# - **Sin embargo**, si la estrategia busca aumentar la cuota de mercado, mejorar la retención, o preparar el terreno para futuros upsells, podría ser justificable.
# - **Sugerencia:** Realizar un test A/B o piloto para validar si la conversión realmente sube a 8% y si la retención mejora. Además, analizar si el precio más bajo puede atraer más usuarios activos mensuales en el futuro.
# - **Alternativa:** Considerar una reducción de precio parcial (por ejemplo, a 24€/mes) y analizar el impacto, o añadir más valor al plan premium para justificar el precio actual.
#
# **En resumen:**
# **Desde el punto de vista financiero inmediato, la reducción de precio no es una decisión óptima.** Solo sería recomendable si hay objetivos estratégicos adicionales (crecimiento, retención, competencia) que justifiquen el cambio.
#
# === COMPLETITUD DEL ANÁLISIS ===
# ✓ Elementos clave cubiertos: 8/8
# ✓ Análisis completo: Sí

# %% [markdown]
# ## Técnicas Avanzadas de CoT

# %%
# Técnica 1: CoT con Auto-Verificación
def cot_con_verificacion():
    print("=== CoT CON AUTO-VERIFICACIÓN ===")
    
    problema = "Una piscina se llena con dos bombas. La bomba A la llena en 4 horas, la bomba B en 6 horas. Si funcionan juntas, ¿en cuánto tiempo llenan la piscina?"
    
    prompt_verificacion = f"""Resuelve este problema paso a paso y luego verifica tu respuesta:
    
{problema}
    
PASO 1 - RESOLUCIÓN:
Piensa paso a paso para encontrar la solución.
    
PASO 2 - VERIFICACIÓN:
Revisa tu cálculo usando un método diferente o verificando que los números tienen sentido.
    
PASO 3 - RESPUESTA FINAL:
Confirma tu respuesta final.
    
Proceso completo:"""
    
    try:
        response = llm.invoke([HumanMessage(content=prompt_verificacion)])
        print("PROBLEMA:")
        print(problema)
        print("\nSOLUCIÓN CON AUTO-VERIFICACIÓN:")
        print(response.content)
        
        # Verificar estructura
        contenido = response.content.lower()
        tiene_resolucion = 'paso 1' in contenido or 'resolución' in contenido
        tiene_verificacion = 'paso 2' in contenido or 'verificación' in contenido
        tiene_final = 'paso 3' in contenido or 'final' in contenido
        
        print("\n=== ESTRUCTURA ===")
        print(f"✓ Resolución: {'Sí' if tiene_resolucion else 'No'}")
        print(f"✓ Verificación: {'Sí' if tiene_verificacion else 'No'}")
        print(f"✓ Respuesta final: {'Sí' if tiene_final else 'No'}")
        
    except Exception as e:
        print(f"Error: {e}")

# Ejecutar CoT con verificación
cot_con_verificacion()
# Out:
# === CoT CON AUTO-VERIFICACIÓN ===
# PROBLEMA:
# Una piscina se llena con dos bombas. La bomba A la llena en 4 horas, la bomba B en 6 horas. Si funcionan juntas, ¿en cuánto tiempo llenan la piscina?
#
# SOLUCIÓN CON AUTO-VERIFICACIÓN:
# ¡Vamos a resolver el problema paso a paso!
#
# ---
#
# **PASO 1 - RESOLUCIÓN**
#
# **1.** Determinamos la tasa de llenado de cada bomba:
#
# - **Bomba A:** Llena la piscina en 4 horas ⇒ en 1 hora llena **1/4** de la piscina.
# - **Bomba B:** Llena la piscina en 6 horas ⇒ en 1 hora llena **1/6** de la piscina.
#
# **2.** Si trabajan juntas, sumamos sus tasas de llenado:
#
# \[
# \text{Tasa conjunta} = \frac{1}{4} + \frac{1}{6}
# \]
#
# Buscamos el común denominador (12):
#
# \[
# \frac{1}{4} = \frac{3}{12}
# \]
# \[
# \frac{1}{6} = \frac{2}{12}
# \]
# \[
# \text{Tasa conjunta} = \frac{3}{12} + \frac{2}{12} = \frac{5}{12}
# \]
#
# Esto significa que juntas llenan **5/12** de la piscina por hora.
#
# **3.** ¿Cuánto tiempo tardan en llenar la piscina completa?
#
# Si en 1 hora llenan 5/12, en **t** horas llenan 1 piscina:
#
# \[
# \frac{5}{12} \cdot t = 1
# \]
# \[
# t = \frac{12}{5}
# \]
# \[
# t = 2.4 \text{ horas}
# \]
#
# ---
#
# **PASO 2 - VERIFICACIÓN**
#
# Verifiquemos de otra manera: ¿Cuánto llenan en 2.4 horas?
#
# \[
# \text{Cantidad llenada} = \frac{5}{12} \times 2.4
# \]
#
# Calculamos:
#
# \[
# 2.4 = \frac{24}{10}
# \]
# \[
# \frac{5}{12} \times \frac{24}{10} = \frac{5 \times 24}{12 \times 10} = \frac{120}{120} = 1
# \]
#
# ¡Sí! En 2.4 horas llenan exactamente una piscina.
#
# ---
#
# **PASO 3 - RESPUESTA FINAL**
#
# **Las dos bombas juntas llenan la piscina en 2.4 horas.**
#
# ---
#
# **Respuesta final:**
# **Las dos bombas juntas llenan la piscina en 2.4 horas.**
#
# === ESTRUCTURA ===
# ✓ Resolución: Sí
# ✓ Verificación: Sí
# ✓ Respuesta final: Sí

# %%
# Técnica 2: CoT Multi-Perspectiva
def cot_multi_perspectiva():
    print("=== CoT MULTI-PERSPECTIVA ===")
    
    dilema = """Una empresa de delivery está considerando implementar un algoritmo de IA 
    para optimizar rutas que podría reducir costos en 20% pero eliminaría 100 empleos 
    de repartidores. ¿Debería implementarlo?"""
    
    prompt_multi = f"""Analiza este dilema desde múltiples perspectivas:
    
{dilema}
    
Analiza paso a paso desde cada perspectiva:
    
PERSPECTIVA 1 - FINANCIERA:
- Beneficios económicos
- Costos de implementación
- ROI a corto y largo plazo
    
PERSPECTIVA 2 - SOCIAL/ÉTICA:
- Impacto en empleados
- Responsabilidad social corporativa
- Percepción pública
    
PERSPECTIVA 3 - ESTRATÉGICA:
- Competitividad del mercado
- Innovación tecnológica
- Sostenibilidad del negocio
    
SÍNTESIS:
- Integra las perspectivas
- Propone soluciones alternativas
- Recomienda curso de acción
    
Análisis completo:"""
    
    try:
        response = llm.invoke([HumanMessage(content=prompt_multi)])
        print("DILEMA EMPRESARIAL:")
        print(dilema)
        print("\nANÁLISIS MULTI-PERSPECTIVA:")
        print(response.content)
        
        # Verificar cobertura de perspectivas
        analisis = response.content.lower()
        perspectivas = ['financiera', 'social', 'ética', 'estratégica', 'síntesis']
        perspectivas_cubiertas = sum(1 for p in perspectivas if p in analisis)
        
        print(f"\n=== COBERTURA DEL ANÁLISIS ===")
        print(f"✓ Perspectivas cubiertas: {perspectivas_cubiertas}/{len(perspectivas)}")
        print(f"✓ Análisis integral: {'Sí' if perspectivas_cubiertas >= 4 else 'Parcial'}")
        
    except Exception as e:
        print(f"Error: {e}")

# Ejecutar análisis multi-perspectiva
cot_multi_perspectiva()
# Out:
# === CoT MULTI-PERSPECTIVA ===
# DILEMA EMPRESARIAL:
# Una empresa de delivery está considerando implementar un algoritmo de IA
#     para optimizar rutas que podría reducir costos en 20% pero eliminaría 100 empleos
#     de repartidores. ¿Debería implementarlo?
#
# ANÁLISIS MULTI-PERSPECTIVA:
# **ANÁLISIS DEL DILEMA: IMPLEMENTACIÓN DE IA EN EMPRESA DE DELIVERY**
#
# ---
#
# ### PERSPECTIVA 1 - FINANCIERA
#
# **Beneficios económicos:**
# - La reducción de costos en un 20% puede representar un ahorro significativo en gastos operativos, especialmente si los salarios de los repartidores constituyen una parte importante del presupuesto.
# - Mayor eficiencia en las rutas puede traducirse en menos gasto de combustible, mantenimiento de vehículos y tiempo de entrega, mejorando la rentabilidad.
#
# **Costos de implementación:**
# - Desarrollo, adquisición e integración del algoritmo de IA pueden requerir una inversión inicial considerable (software, hardware, capacitación).
# - Costos de despido o indemnización para los 100 empleados afectados.
# - Posibles gastos legales o de relaciones públicas si hay resistencia o controversia.
#
# **ROI a corto y largo plazo:**
# - A corto plazo, el ROI puede verse afectado por los costos de implementación y despidos.
# - A largo plazo, la reducción de costos operativos y la mejora en la eficiencia pueden generar mayores márgenes de ganancia y recursos para reinvertir en el negocio.
#
# ---
#
# ### PERSPECTIVA 2 - SOCIAL/ÉTICA
#
# **Impacto en empleados:**
# - 100 personas perderían su empleo, lo que puede afectar su bienestar económico y emocional, así como el de sus familias.
# - Puede generar descontento interno y afectar la moral de los empleados restantes.
#
# **Responsabilidad social corporativa:**
# - La empresa tiene la responsabilidad de considerar el impacto social de sus decisiones, especialmente en comunidades donde el empleo es escaso.
# - Despedir empleados por automatización puede ser visto como una falta de compromiso con el desarrollo social y humano.
#
# **Percepción pública:**
# - La opinión pública puede volverse negativa si se percibe que la empresa prioriza ganancias sobre las personas.
# - Riesgo de boicots, mala prensa o pérdida de clientes sensibles a temas sociales.
#
# ---
#
# ### PERSPECTIVA 3 - ESTRATÉGICA
#
# **Competitividad del mercado:**
# - Adoptar IA puede posicionar a la empresa como líder en eficiencia y tecnología, permitiéndole competir mejor frente a rivales que aún no han automatizado.
# - Si los competidores ya usan IA, no implementarla podría dejar a la empresa en desventaja.
#
# **Innovación tecnológica:**
# - La integración de IA puede abrir puertas a nuevas oportunidades de negocio, servicios personalizados y expansión.
# - Fomenta una cultura de innovación y adaptación al cambio.
#
# **Sostenibilidad del negocio:**
# - La automatización puede hacer que el negocio sea más resiliente ante fluctuaciones de demanda y costos laborales.
# - Sin embargo, la sostenibilidad también implica mantener una buena relación con la comunidad y empleados.
#
# ---
#
# ### SÍNTESIS
#
# **Integración de perspectivas:**
# - Desde lo financiero y estratégico, la implementación de IA parece ventajosa por ahorro de costos y mejora competitiva.
# - Sin embargo, el impacto social y ético es significativo y puede tener repercusiones negativas a largo plazo en reputación y relaciones comunitarias.
#
# **Soluciones alternativas:**
# 1. **Reentrenamiento y recolocación:** Ofrecer capacitación a los repartidores para asumir nuevos roles dentro de la empresa (logística, atención al cliente, mantenimiento de sistemas de IA).
# 2. **Implementación gradual:** Automatizar solo una parte de las rutas, permitiendo una transición más suave y tiempo para que los empleados se adapten.
# 3. **Compensación y apoyo:** Proporcionar paquetes de indemnización justos y apoyo para la búsqueda de empleo o emprendimiento.
# 4. **Colaboración con la comunidad:** Invertir en programas sociales o alianzas con organizaciones locales para mitigar el impacto del desempleo.
#
# **Recomendación de curso de acción:**
# - La empresa debería considerar una **implementación gradual** del algoritmo de IA, acompañada de un **plan robusto de reentrenamiento y recolocación** para los empleados afectados.
# - Comunicar de manera transparente las razones y beneficios de la automatización, mostrando compromiso con la responsabilidad social.
# - Evaluar periódicamente el impacto social y ajustar la estrategia según los resultados y la retroalimentación de empleados y clientes.
#
# **Conclusión:**
# La automatización es inevitable en muchos sectores, pero su adopción debe ser gestionada con sensibilidad social y ética. Un enfoque equilibrado puede permitir a la empresa beneficiarse de la tecnología sin sacrificar su reputación ni su responsabilidad con la comunidad.
#
# === COBERTURA DEL ANÁLISIS ===
# ✓ Perspectivas cubiertas: 5/5
# ✓ Análisis integral: Sí

# %% [markdown]
# ## CoT para Debugging de Código
#
# Una aplicación práctica muy útil: usar CoT para analizar y debuggear código.

# %%
# CoT para debugging de código
def cot_debugging():
    print("=== CoT PARA DEBUGGING DE CÓDIGO ===")
    
    codigo_con_bug = '''def calcular_promedio(numeros):
    total = 0
    for numero in numeros:
        total += numero
    promedio = total / len(numeros)
    return promedio

# Uso
datos = []
resultado = calcular_promedio(datos)
print(f"El promedio es: {resultado}")'''
    
    prompt_debugging = f"""Analiza este código paso a paso para encontrar problemas:
    
```python
{codigo_con_bug}
```
    
PASO 1 - COMPRENSIÓN:
¿Qué se supone que hace este código?
    
PASO 2 - ANÁLISIS LÍNEA POR LÍNEA:
Examina cada línea en busca de problemas potenciales.
    
PASO 3 - IDENTIFICACIÓN DE PROBLEMAS:
¿Qué errores o problemas específicos encuentras?
    
PASO 4 - CASOS PROBLEMÁTICOS:
¿En qué situaciones fallaría este código?
    
PASO 5 - SOLUCIÓN:
¿Cómo arreglarías estos problemas?
    
Análisis de debugging:"""
    
    try:
        response = llm.invoke([HumanMessage(content=prompt_debugging)])
        print("CÓDIGO A ANALIZAR:")
        print(codigo_con_bug)
        print("\nANÁLISIS DE DEBUGGING:")
        print(response.content)
        
        # Verificar si encontró el problema principal
        analisis = response.content.lower()
        encontro_division_cero = any(term in analisis for term in ['división', 'cero', 'vacía', 'empty'])
        propuso_solucion = 'if' in analisis or 'len(' in analisis or 'excepción' in analisis
        
        print(f"\n=== EFECTIVIDAD DEL DEBUGGING ===")
        print(f"✓ Identificó división por cero: {'Sí' if encontro_division_cero else 'No'}")
        print(f"✓ Propuso solución: {'Sí' if propuso_solucion else 'No'}")
        
    except Exception as e:
        print(f"Error: {e}")

# Ejecutar debugging
cot_debugging()
# Out:
# === CoT PARA DEBUGGING DE CÓDIGO ===
# CÓDIGO A ANALIZAR:
# def calcular_promedio(numeros):
#     total = 0
#     for numero in numeros:
#         total += numero
#     promedio = total / len(numeros)
#     return promedio
#
# # Uso
# datos = []
# resultado = calcular_promedio(datos)
# print(f"El promedio es: {resultado}")
#
# ANÁLISIS DE DEBUGGING:
# Claro, aquí tienes el análisis paso a paso:
#
# ---
#
# ### PASO 1 - COMPRENSIÓN
#
# **¿Qué se supone que hace este código?**
#
# El código define una función `calcular_promedio` que recibe una lista de números y calcula su promedio (media aritmética). Luego, crea una lista vacía `datos`, llama a la función con esa lista y muestra el resultado.
#
# ---
#
# ### PASO 2 - ANÁLISIS LÍNEA POR LÍNEA
#
# ```python
# def calcular_promedio(numeros):
#     total = 0
#     for numero in numeros:
#         total += numero
#     promedio = total / len(numeros)
#     return promedio
# ```
# - **Línea 1:** Define la función `calcular_promedio` que toma un argumento `numeros`.
# - **Línea 2:** Inicializa la variable `total` en 0.
# - **Línea 3-4:** Itera sobre cada elemento en `numeros` y suma su valor a `total`.
# - **Línea 5:** Calcula el promedio dividiendo el total entre la cantidad de elementos en `numeros`.
# - **Línea 6:** Retorna el promedio calculado.
#
# ```python
# datos = []
# resultado = calcular_promedio(datos)
# print(f"El promedio es: {resultado}")
# ```
# - **Línea 8:** Crea una lista vacía `datos`.
# - **Línea 9:** Llama a la función con la lista vacía y guarda el resultado en `resultado`.
# - **Línea 10:** Imprime el resultado.
#
# ---
#
# ### PASO 3 - IDENTIFICACIÓN DE PROBLEMAS
#
# **Problemas específicos:**
#
# - **División por cero:** Si la lista `numeros` está vacía, `len(numeros)` es 0, lo que causa un error de división por cero en la línea `promedio = total / len(numeros)`.
# - **Sin manejo de errores:** No hay manejo de excepciones ni validación de entrada.
# - **No verifica el tipo de elementos:** Si la lista contiene elementos no numéricos, podría causar errores.
# - **No maneja listas vacías de forma amigable:** No informa al usuario que no se puede calcular el promedio de una lista vacía.
#
# ---
#
# ### PASO 4 - CASOS PROBLEMÁTICOS
#
# **Situaciones en las que fallaría:**
#
# - **Lista vacía:** Como en el ejemplo, `datos = []` produce una división por cero.
# - **Lista con elementos no numéricos:** Por ejemplo, `datos = [1, 'a', 3]` causaría un error al intentar sumar una cadena a un entero.
# - **Lista con valores especiales:** Por ejemplo, `datos = [None, 1, 2]` también causaría un error.
#
# ---
#
# ### PASO 5 - SOLUCIÓN
#
# **¿Cómo arreglar estos problemas?**
#
# 1. **Manejo de listas vacías:** Verificar si la lista está vacía antes de calcular el promedio.
# 2. **Validación de tipos:** Asegurarse de que todos los elementos sean numéricos.
# 3. **Manejo de errores:** Usar excepciones para informar al usuario de problemas.
#
# **Código corregido:**
#
# ```python
# def calcular_promedio(numeros):
#     if not numeros:
#         raise ValueError("La lista de números está vacía. No se puede calcular el promedio.")
#     # Filtrar solo elementos numéricos
#     numeros_validos = [n for n in numeros if isinstance(n, (int, float))]
#     if len(numeros_validos) != len(numeros):
#         raise TypeError("La lista contiene elementos no numéricos.")
#     total = sum(numeros_validos)
#     promedio = total / len(numeros_validos)
#     return promedio
#
# # Uso
# datos = []
# try:
#     resultado = calcular_promedio(datos)
#     print(f"El promedio es: {resultado}")
# except Exception as e:
#     print(f"Error: {e}")
# ```
#
# **Explicación de la solución:**
# - Se verifica si la lista está vacía y se lanza una excepción con un mensaje claro.
# - Se filtran los elementos para asegurarse de que sean numéricos.
# - Se maneja cualquier excepción al llamar a la función, mostrando un mensaje de error amigable.
#
# ---
#
# **Resumen del debugging:**
# - El código original falla con listas vacías y elementos no numéricos.
# - Se debe validar la entrada y manejar errores para evitar caídas inesperadas y mejorar la experiencia del usuario.
#
# === EFECTIVIDAD DEL DEBUGGING ===
# ✓ Identificó división por cero: Sí
# ✓ Propuso solución: Sí

# %% [markdown]
# # Ejercicio con Chain of Thought

# %%
# Ejercicio final: Diseña tu propio CoT prompt
def ejercicio_cot():
    print("=== EJERCICIO: DISEÑA TU CoT PROMPT ===")
    print("\nTarea: Crear un sistema CoT para análisis de inversión")
    print("\nEscenario:")
    print("Una persona tiene 10,000€ para invertir y está considerando tres opciones:")
    print("1. Acciones de tech (retorno esperado 12% anual, riesgo alto)")
    print("2. Bonos gubernamentales (retorno 3% anual, riesgo bajo)")
    print("3. Fondo mixto (retorno 7% anual, riesgo medio)")
    print("\nLa persona es joven (25 años) y puede asumir riesgo moderado.")
    
    # Template para el estudiante
    template_cot = """
    # TU PROMPT CoT AQUÍ:
    
    Analiza esta decisión de inversión paso a paso:
    
    [ESCENARIO]
    
    PASO 1 - PERFIL DEL INVERSOR:
    - Analiza edad, tolerancia al riesgo, horizonte temporal
    
    PASO 2 - ANÁLISIS DE OPCIONES:
    - Evalúa cada opción: retorno, riesgo, liquidez
    
    PASO 3 - ESTRATEGIA DE DIVERSIFICACIÓN:
    - Considera combinar opciones
    
    PASO 4 - RECOMENDACIÓN:
    - Proporciona recomendación específica con justificación
    
    Análisis de inversión:
    """
    
    print("\nDiseña un prompt CoT estructurado:")
    print(template_cot)
    
    # Prompt de ejemplo bien diseñado
    prompt_ejemplo = """Analiza esta decisión de inversión usando razonamiento paso a paso:
    
SITUACIÓN:
Inversor de 25 años con 10,000€ considerando:
- Acciones tech: 12% retorno anual, riesgo alto
- Bonos: 3% retorno anual, riesgo bajo  
- Fondo mixto: 7% retorno anual, riesgo medio
Tolerancia: riesgo moderado
    
PASO 1 - PERFIL DEL INVERSOR:
Analiza edad, horizonte temporal y tolerancia al riesgo.
    
PASO 2 - EVALUACIÓN DE OPCIONES:
Para cada opción, calcula:
- Valor esperado en 10 años
- Nivel de riesgo vs. perfil
- Pros y contras específicos
    
PASO 3 - ESTRATEGIA DE PORTFOLIO:
Considera distribución óptima entre opciones basada en:
- Diversificación de riesgo
- Maximización de retorno ajustado por riesgo
- Liquidez y flexibilidad
    
PASO 4 - RECOMENDACIÓN FINAL:
Proporciona distribución específica (porcentajes) con:
- Justificación detallada
- Proyección a 10 años
- Consideraciones adicionales
    
Análisis completo:"""
    
    print("\n=== PROMPT DE REFERENCIA ===")
    print(prompt_ejemplo)
    
    # Ejecutar el prompt ejemplo
    print("\n=== RESULTADO DEL ANÁLISIS ===")
    try:
        response = llm.invoke([HumanMessage(content=prompt_ejemplo)])
        print(response.content)
        
        # Análisis de la respuesta
        analisis = response.content.lower()
        elementos = ['perfil', 'evaluación', 'portfolio', 'recomendación', '%', '€', 'años']
        elementos_presentes = sum(1 for elem in elementos if elem in analisis)
        
        print(f"\n=== CALIDAD DEL ANÁLISIS ===")
        print(f"✓ Elementos clave: {elementos_presentes}/{len(elementos)}")
        print(f"✓ Análisis completo: {'Sí' if elementos_presentes >= 5 else 'Parcial'}")
        
    except Exception as e:
        print(f"Error: {e}")

# Ejecutar ejercicio
ejercicio_cot()
# Out:
# === EJERCICIO: DISEÑA TU CoT PROMPT ===
#
# Tarea: Crear un sistema CoT para análisis de inversión
#
# Escenario:
# Una persona tiene 10,000€ para invertir y está considerando tres opciones:
# 1. Acciones de tech (retorno esperado 12% anual, riesgo alto)
# 2. Bonos gubernamentales (retorno 3% anual, riesgo bajo)
# 3. Fondo mixto (retorno 7% anual, riesgo medio)
#
# La persona es joven (25 años) y puede asumir riesgo moderado.
#
# Diseña un prompt CoT estructurado:
#
#     # TU PROMPT CoT AQUÍ:
#
#     Analiza esta decisión de inversión paso a paso:
#
#     [ESCENARIO]
#
#     PASO 1 - PERFIL DEL INVERSOR:
#     - Analiza edad, tolerancia al riesgo, horizonte temporal
#
#     PASO 2 - ANÁLISIS DE OPCIONES:
#     - Evalúa cada opción: retorno, riesgo, liquidez
#
#     PASO 3 - ESTRATEGIA DE DIVERSIFICACIÓN:
#     - Considera combinar opciones
#
#     PASO 4 - RECOMENDACIÓN:
#     - Proporciona recomendación específica con justificación
#
#     Análisis de inversión:
#
#
# === PROMPT DE REFERENCIA ===
# Analiza esta decisión de inversión usando razonamiento paso a paso:
#
# SITUACIÓN:
# Inversor de 25 años con 10,000€ considerando:
# - Acciones tech: 12% retorno anual, riesgo alto
# - Bonos: 3% retorno anual, riesgo bajo
# - Fondo mixto: 7% retorno anual, riesgo medio
# Tolerancia: riesgo moderado
#
# PASO 1 - PERFIL DEL INVERSOR:
# Analiza edad, horizonte temporal y tolerancia al riesgo.
#
# PASO 2 - EVALUACIÓN DE OPCIONES:
# Para cada opción, calcula:
# - Valor esperado en 10 años
# - Nivel de riesgo vs. perfil
# - Pros y contras específicos
#
# PASO 3 - ESTRATEGIA DE PORTFOLIO:
# Considera distribución óptima entre opciones basada en:
# - Diversificación de riesgo
# - Maximización de retorno ajustado por riesgo
# - Liquidez y flexibilidad
#
# PASO 4 - RECOMENDACIÓN FINAL:
# Proporciona distribución específica (porcentajes) con:
# - Justificación detallada
# - Proyección a 10 años
# - Consideraciones adicionales
#
# Análisis completo:
#
# === RESULTADO DEL ANÁLISIS ===
# Claro, aquí tienes un análisis detallado paso a paso:
#
# ---
#
# ## PASO 1 - PERFIL DEL INVERSOR
#
# **Edad:** 25 años
# **Horizonte temporal:** Largo plazo (10 años o más)
# **Tolerancia al riesgo:** Moderada
#
# **Análisis:**
# - **Edad joven**: Puede asumir cierto riesgo, ya que tiene tiempo para recuperarse de posibles caídas.
# - **Horizonte largo**: Permite aprovechar la capitalización compuesta y soportar volatilidad a corto plazo.
# - **Tolerancia moderada**: No se siente cómodo con grandes pérdidas, pero tampoco busca solo seguridad.
#
# **Conclusión:**
# El inversor puede permitirse una exposición significativa a activos de riesgo, pero debe evitar una cartera extremadamente volátil.
#
# ---
#
# ## PASO 2 - EVALUACIÓN DE OPCIONES
#
# ### 1. Acciones Tech
# - **Retorno anual esperado:** 12%
# - **Riesgo:** Alto
#
# **Valor esperado en 10 años:**
# \( 10,000 \times (1 + 0.12)^{10} = 10,000 \times 3.1058 = 31,058 € \)
#
# **Pros:**
# - Alto potencial de crecimiento.
# - Aprovecha el largo plazo.
#
# **Contras:**
# - Alta volatilidad; riesgo de caídas fuertes.
# - Puede no alinearse totalmente con tolerancia moderada.
#
# ---
#
# ### 2. Bonos
# - **Retorno anual esperado:** 3%
# - **Riesgo:** Bajo
#
# **Valor esperado en 10 años:**
# \( 10,000 \times (1 + 0.03)^{10} = 10,000 \times 1.3439 = 13,439 € \)
#
# **Pros:**
# - Estabilidad y protección de capital.
# - Bajo riesgo de pérdida.
#
# **Contras:**
# - Retorno bajo, especialmente frente a inflación.
# - Menor crecimiento a largo plazo.
#
# ---
#
# ### 3. Fondo Mixto
# - **Retorno anual esperado:** 7%
# - **Riesgo:** Medio
#
# **Valor esperado en 10 años:**
# \( 10,000 \times (1 + 0.07)^{10} = 10,000 \times 1.9672 = 19,672 € \)
#
# **Pros:**
# - Equilibrio entre crecimiento y estabilidad.
# - Diversificación interna.
#
# **Contras:**
# - Retorno menor que acciones, mayor riesgo que bonos.
# - Puede tener comisiones.
#
# ---
#
# ## PASO 3 - ESTRATEGIA DE PORTFOLIO
#
# **Objetivos:**
# - Diversificar para reducir riesgo.
# - Maximizar retorno ajustado al riesgo.
# - Mantener liquidez y flexibilidad.
#
# **Consideraciones:**
# - **Diversificación:** Combinar activos reduce la volatilidad total.
# - **Maximización de retorno/riesgo:** El fondo mixto es adecuado para el perfil, pero incluir algo de acciones tech puede mejorar el retorno esperado.
# - **Liquidez:** Todos los instrumentos suelen ser líquidos, pero los fondos pueden tener ciertas restricciones.
#
# **Distribución óptima sugerida:**
# - **Acciones tech:** 40%
# - **Fondo mixto:** 40%
# - **Bonos:** 20%
#
# **Justificación:**
# - Acciones tech aportan crecimiento, pero no dominan la cartera.
# - Fondo mixto equilibra riesgo y retorno.
# - Bonos aportan estabilidad y protección ante caídas.
#
# ---
#
# ## PASO 4 - RECOMENDACIÓN FINAL
#
# ### **Distribución sugerida:**
# - **Acciones tech:** 40% (4,000 €)
# - **Fondo mixto:** 40% (4,000 €)
# - **Bonos:** 20% (2,000 €)
#
# ### **Proyección a 10 años (valor esperado):**
#
# | Opción         | %      | Inversión inicial | Valor esperado (10 años) |
# |----------------|--------|-------------------|--------------------------|
# | Acciones tech  | 40%    | 4,000 €           | 12,423 €                 |
# | Fondo mixto    | 40%    | 4,000 €           | 7,869 €                  |
# | Bonos          | 20%    | 2,000 €           | 2,688 €                  |
# | **Total**      | 100%   | 10,000 €          | **22,980 €**             |
#
# ### **Justificación detallada:**
# - **Retorno esperado**: 22,980 € (más del doble del capital inicial).
# - **Riesgo ajustado**: La exposición a acciones tech se modera con el fondo mixto y los bonos.
# - **Diversificación**: Reduce la volatilidad y el riesgo de grandes pérdidas.
# - **Flexibilidad**: Puede reajustar la cartera según cambie su perfil o el mercado.
#
# ### **Consideraciones adicionales:**
# - Revisar la cartera cada 1-2 años y rebalancear si alguna clase de activo crece o cae mucho.
# - Considerar costes y comisiones de los fondos.
# - Mantener un pequeño fondo de emergencia fuera de esta inversión.
# - Si la tolerancia al riesgo cambia, ajustar la proporción de bonos.
#
# ---
#
# ## **RESUMEN**
#
# - **Perfil joven, horizonte largo, riesgo moderado.**
# - **Distribución sugerida:** 40% acciones tech, 40% fondo mixto, 20% bonos.
# - **Valor esperado en 10 años:** ~22,980 €.
# - **Ventajas:** Buen equilibrio entre crecimiento y seguridad, diversificación, flexibilidad.
# - **Recomendación:** Revisar y ajustar periódicamente según evolución personal y de mercado.
#
# === CALIDAD DEL ANÁLISIS ===
# ✓ Elementos clave: 7/7
# ✓ Análisis completo: Sí

# %% [markdown]
# ## Limitaciones y Consideraciones de CoT
#
# ### ✅ Cuándo Usar CoT:
# - Problemas matemáticos complejos
# - Razonamiento lógico multi-paso
# - Análisis que requiere transparencia
# - Cuando necesitas verificar el proceso
# - Problemas donde el "por qué" es importante
#
# ### ⚠️ Limitaciones:
# - **Más tokens**: Respuestas más largas = mayor costo
# - **Tiempo**: Razonamiento paso a paso toma más tiempo
# - **Complejidad innecesaria**: Para problemas simples puede ser excesivo
# - **Razonamiento erróneo**: Puede mostrar lógica incorrecta convincente
#
# ### 🎯 Mejores Prácticas:
# 1. **Estructura clara**: Define pasos específicos
# 2. **Verificación**: Incluye auto-verificación cuando sea posible
# 3. **Ejemplos**: Usa few-shot para mostrar patrón deseado
# 4. **Temperatura baja**: Para razonamiento más consistente
# 5. **Validación externa**: Verifica respuestas críticas independientemente

# %% [markdown]
# ## Conceptos Clave Aprendidos
#
# 1. **Chain-of-Thought** mejora dramáticamente la precisión en problemas complejos
# 2. **Zero-shot CoT** es tan simple como agregar "piensa paso a paso"
# 3. **Few-shot CoT** combina ejemplos con razonamiento para mejor control
# 4. **Estructura explícita** guía el razonamiento hacia análisis completos
# 5. **Auto-verificación** aumenta la confiabilidad de las respuestas
#
# ## Próximos Pasos
#
# En el siguiente notebook exploraremos **Técnicas Avanzadas** como Tree of Thoughts (ToT), Self-Consistency, y otras metodologías cutting-edge que llevan el prompt engineering al siguiente nivel.
#
# ### Para Practicar:
# 1. Aplica CoT a problemas de tu dominio específico
# 2. Experimenta con diferentes niveles de estructura
# 3. Compara precisión con y sin CoT
# 4. Desarrolla patrones de verificación personalizados
